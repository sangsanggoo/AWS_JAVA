# %% [markdown]
# ### 전국로컬푸드인증정보표준데이터
# * 인기품목 top10(품목별 카운트)
# * dictionary 작성 : {군단위 지역명: [품목명]}
# * dictionary 작성 : {품목 : [군단위 지역명]}
# * jupyter note 업로드 : 이름_로컬푸드jpynb
# * 192.168.2.101:8000/upload

# %%
import numpy as np
def my_split1(s):
    block_start = False
    start_index = 0
    ret_list=[]
    for i, c in enumerate(s):
        if block_start==False:
            if c=='+':
                ret_list.append(s[start_index:i])
                start_index=i+1
            elif c=='"':
                block_start=True
                start_index = i
        else:
            if c=='"':
                block_start=False
    if s[-1]!='+':
        ret_list.append(s[start_index:])
    return ret_list
def my_split2(s):
    block_start = False
    start_index = 0
    ret_list=[]
    for i, c in enumerate(s):
        if block_start==False:
            if c==',':
                ret_list.append(s[start_index:i])
                start_index=i+1
            elif c=='"':
                block_start=True
                start_index = i
        else:
            if c=='"':
                block_start=False
    if s[-1]!=',':
        ret_list.append(s[start_index:])
    return ret_list
def my_split3(s): # 외 없애기
    for i in s :
        if('외' in s) :
            print('외가 있음')
        else : 
            print('외가 없음')

# %%
data_list = []
data_list_name = []
data_list_name_noplus = [] # 품목 + 있는거를 리스트로 바꾸기
data_list_name_noplus_list = [] # 품목 2개이상 있는거 랑 한개있는거 하나로 리스트화
data_list_name_noplus_set = ()
data_list_name_noplus_set_list  = [] # 중복 제거한것을 다시 list화 시킨것
data_list_name_noplus_set_list_count = [] #중복 제거한거 갯수 넣을용
data_list_name_noplus_count_rank = [] 
data_list_name_noplus_count_rank_10 = [] # 갯수 상위 10등
data_list_name_noplus_nodot = [] #주소가 ''인 품목들 없앤거
data_list_country = []
data_list_country_nodot = [] #주소가 ''인 주소 없애기
with open('전국로컬푸드인증정보표준데이터.csv') as f :
    for line in f :
        data_list.append(my_split2(line))
    for i in data_list[1:] :
        data_list_country.append(i[4])
        data_list_name.append(i[8])  #품목명 (+포함)
    for i in data_list_name :
        if '+' in i :
            data_list_name_noplus.append(my_split1(i))
        elif ',' in i :
            data_list_name_noplus.append(my_split2(i))
        else :
            data_list_name_noplus.append(i)
            
    for i in data_list_name_noplus :
        if type(i) == str :
            data_list_name_noplus_list.append(i)
        elif type(i) == list :
            for e in i :
                data_list_name_noplus_list.append(e)
    data_list_name_noplus_set=set(data_list_name_noplus_list)
    for i in data_list_name_noplus_set :
        data_list_name_noplus_count_rank.append(data_list_name_noplus_list.count(i))
        data_list_name_noplus_set_list.append(i)
        data_list_name_noplus_set_list_count.append(data_list_name_noplus_list.count(i))
    
    data_list_name_noplus_count_rank_10=(sorted(data_list_name_noplus_count_rank[:],reverse=True))[:10] # 품목 상위 10개 판매개수
    for i in data_list_name_noplus_count_rank_10 :
        print(data_list_name_noplus_set_list[data_list_name_noplus_set_list_count.index(i)],i,'개')
    for n,i in enumerate(data_list_country) :
        if i!='' :
            data_list_country_nodot.append((i.split(' '))[1])
            data_list_name_noplus_nodot.append(data_list_name_noplus[n])
#d=dict(zip(data_list_country_nodot,data_list_name_noplus_nodot))
#print(d)
data_list_name2_nodot_setlist = []
# Out:
# 대파 499 개
# 상추 460 개
# 배추 416 개
# 감자 399 개
# 무 362 개
# 고구마 342 개
# 고추 289 개
# 쪽파 287 개
# 시금치 280 개
# 부추 264 개

# %%
for n,i in enumerate(data_list_country_nodot) :
    if i == '옥천군안내면' :
        data_list_country_nodot[n] = '옥천군' 
data_list_country_nodot_setlist = list(set(data_list_country_nodot))
data_list_name_nodot_setlist = []
for i in range(len(data_list_country_nodot_setlist)) :
    data_list_name_nodot_setlist.append([]) #리스트 안에 도시 개수만큼 리스트 만들기
#print(data_list_name_nodot_setlist)
#print(data_list_country_nodot_setlist)
for n,i in enumerate(data_list_country_nodot) :
    if type(data_list_name_noplus_nodot[n]) == list:
        for f in data_list_name_noplus_nodot[n] :
            data_list_name_nodot_setlist[data_list_country_nodot_setlist.index(i)].append(f)
    else :
        data_list_name_nodot_setlist[data_list_country_nodot_setlist.index(i)].append(data_list_name_noplus_nodot[n])
for i,n in enumerate(data_list_name_nodot_setlist) :
    data_list_name_nodot_setlist[i] = set(n)
d=dict(zip(data_list_country_nodot_setlist,data_list_name_nodot_setlist))
#d 딕셔너리화 시킨거임
a = str
print(data_list_country_nodot_setlist)
a = input('지역명 : ')
print(d[a])
# Out:
# ['옥천군', '함양군', '원주시', '수원시', '아산시', '화성시', '오산시', '군산시', '완주군']
# 지역명 : 오산시
# {'콩물', '두부', '미숫가루'}

# %%
for i in range(len(data_list_name_noplus_set_list)) :
    data_list_name2_nodot_setlist.append([]) #리스트 안에 도시 개수만큼 리스트 만들기
print(data_list_name2_nodot_setlist)
print(data_list_name_noplus_set_list)
print(data_list_name_noplus021.)
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ...
# [' 당뇨', '양배추(광양_제휴)', '우리밀김치라면', '포도(거봉)', 'C반)유정란', '콜라비잎', '무농약메주-송광', '유기농계란', '양파 외 4품목', '토란(건토란)', '숙주나물', '자두 외 4품목', '엉겅퀴꽃(건엉겅퀴꽃)', '돼지등심덧살', '곤충가공품', '카라향', '콩(껍질콩)', '와송(냉동와송)', '하늘녹차(우전) ', '야생화', '생강(깐생강)', '산양삼(새싹삼)', '기획행사_우유', '자엽아카시아', 'C여)표고버섯(건표고버섯)', '산채류(기타)', '머위', '쌀(밀키퀸)', '고추 외 2품목', '쌈채소(항암쌈채)', '고로쇠 수액', '편백손잡이사각트레이_백이산', '고구마(건고구마)', '삼나물', '참한솔민속엿기름', '마늘(풋마늘', '순천만함초분말', '채가네배즙애_순순순', ' 늙은', '감식초-노고치농원', '참서대 3미', '울타리콩 외 3품목', '우슬뿌리(건우슬뿌리)', '송고버섯', '얼갈이배추', '감자(자색)', '이엠친환경비누(진주)', '고추(수비초)', '헛개나무(열매)', '대추', '둥굴레', '핫케이크가루', '꿀떡', '한련화', '작두콩알', '잠실뽕잎차(티백)', '오이(노각)', '자연그대로참기름', '황가네전통된장', '착한무를품은비트차-순순순', '헛개열매(건)', 'C카)배', '순천만 꾸지뽕 열매환_순순순', '배로과자', '대두', '팥(예팥', '해브원들기름', '차류', '고추(베트남고추)', '두릅(민두릅)', '고추(롱그린', '자염', '연근가루(하늘농장)-순순순', '염색손수건', '고구마줄기(껍질깐)', '현미', '꾸지뽕열매', '피마자잎(아주까리잎)', '감태_제휴', '참비름', '여주(건여주)', '비름나물', '오성고춧가루', '현미꾸지뽕차(미쁘다꽃초)_순순순', '족발세트', '감식초)', '땅콩(새싹)', '흑보찰쌀과자_순순순', '상추(적상추)', '무순', '벼', '달큰이 배칩_순순순', '은혜호밀청국장환', '플럼코트(하모니)', '오크라', ' 아삭이꽈리)', ' 아삭이', '바실 등 19)', '청태곱창김(진도_제휴)', '허브(바질', '해듬정어리액젓', '순천만목련꽃차', '옥수수', '초석잠(건초석잠)', '김밥용구운김', '자색무', '방앗잎', '별량염전함초자염', '상추(아삭이)', '고구마조청-송광', '백향과(숙성)', '시몬카스테라', '엉겅퀴뿌리(건엉겅퀴뿌리)', '포도', '양파(광양-제휴)', '무(서동무)', '"마늘, 양파"', '아로니아 쌈장-서당골', '싸리순', '연꽃에센스 미스트', '표고버섯분말-송광', '도라지분말', 'C여)콩(백태)', '어성초', '보리 외 1', '자옥) 외 2품목', '청각(완도)', '조청3종(쌀', '취나물', '화초', '고구마줄기', '무(순무)', ' 청쌈배추', '고추(꽈리고추)', '엿기름-순순순', '새싹보리현미쌀과자_순순순', '어린새싹보리순분말세트', '구구농원유정란(초란)', 'C카)야관문차티백', '탱자(지실)', '모링가차(티백)-모던팜', '어린잎새싹', '고야', '옻(순) 외 4품목', '갈대김부각선물세트_자연맛길', '잠실오디액', '포도(홍삼척)', '개랭이갓피클', '감말랭이-조계산', '손수건', '머위잎', '양념고추장삼겹살', 'C반)건토란줄기', '굿모링가1호(환', '돼지등갈비', '무청', '달빛품은 사과주스_순순순', '우유식빵', '고구마(황금)', '마늘과자', '돼지목삼겹', '삼색절편', '사과(홍드림)', '토마토', '밤(깐밤)', '순천만국화차', '당귀뿌리(건당귀뿌리)', '오리로스', 'C여)느타리버섯', '고사리(삶은고사리)', '포도 외 11품목', '감자 외 3품목', '곤드레', '순천만블루베리진액_순순순', '연농원1호(연근차', '울금생강엿', '장류3종-송광', '고추(찐아삭이', '하늘겨우살이차 ', '포포 외 1품목', '야콘한과세트-곽씨네', '사과 외 3품목', '소복소복 편강 100g', '로얄제리', '모닝빵', '어린새싹보리순분말-순순순', '"감자, 고구마"', '호림이네 재래들김(진도_제휴)', '묘목', '배(만풍)', '우리밀밀싹국수', ' 청겨자', '여주환-생기들녘', '즙', '감자외 7품목', '적새우살', '녹차-가천산방', 'C반)천일염', '부처손', '요구르트', ' 감자밭콩', '모링가환-생기들녘', '야관문', '딸기 외 6품목', '콩(백태', '밥톳_아라온', '돼지미전지', '올리비아', '해울누리엿기름', '대부도재래김', '콩(선비콩)', ' 비타민', '빵빠레', '모링가 차3종 선물세트', '건새우', '매실(홍)', '근대)', '발디', '삼각스카프', '돼지양념불갈비', '양배추외 19품목', 'C카)백향과', '배추(항암쌈배추)', '착한엄마보리차', '꽃기린', '돌산갓', '미니사과(루비에스)', '고구마 외 5품목', '산양삼 음료', '오이) 외 3품목', '양배추환(이쁘니총각)_순순순', '고구마(밤)', '복분자(냉동복분자)', '매실원액-참과일촌', '방울토마토 외 2품목', '카틀레야', '구구농원유정란', '배추(쌈배추)', '대추토마토 외 13품목', '김치', '독활뿌리', '함초무장아찌', '사과(아오리)', '흑두루미쌀누룽지', '잠실오디조청', '쌍지뜰깐밥쿠키', '방물토마토', '순수배로즙', 'C반)오이(백다다기)', '고추(아삭이', '고추(곡성초)', '순천만갈대쌀생국수', '레드향', '마스크', '별량염전자염3종', '곰취', '미들래배즙', '무릎담요', '블랙베리 외 18품목', '가래떡', '검은들깨가루-순순순', '돌미나리', '보리차(음료)', '감자 외 7품목', '미나리쿠키', '참한솔분말청국장', '장미빛보리분말_순순순', '블루베리방울유과_쌍지뜰', 'C카)키위(그린)', '대부도재래식돌김(전장조미김)', '샐러리)', '히말리아등불', '4호 수산물세트', '블루베리(핑크레몬레이드)', '돼지전지', '혼합현미', '백년초', '메주콩', '귤', '돼지등심', '깐바지락(광양)', '본래족발스페셜세트', '블루베리)', '배(황금)', '효향 한끼누룽지세트', '스테비아', '돼지곱창', '감자(깐감자)', '딸기잼-고산', '세트 2호(새싹보리', '사과', '꾸지뽕가지', '함초소금)', '맨드라미꽃(건맨드라미꽃)', '신령호두', '산딸기', '착한농부쌀과자', '청양고추', '단감(조추)', '둥근마', '무늬호랑가시', '벚굴', '1(세트)-모후실', '친환경생활제품세트(3호)', '과일무', '시금치 외 1품목', 'C카)파프리카', '고구마(꿀)', '매실엑기스', '포도(캠벨)', '달큰이세트(배칩', '나물취', '단삼', '순천만함초자염420g*2', 'C카)미나리쿠키', '사과즙', '목련꽃(건목련꽃)', '배추뿌리', '고들차_순천고들兮藪뎨竄또嵐萱', '고추(청양고추)', '오미자(건오미자)', '목련꽃차', '겨자', '민물고기(다슬기', ' 호랑이콩)', '매실)-참과일촌', '울타리콩 외 3', '복숭아(천중도)', '감귤', '마늘(토종)', '녹두', '블루베리 외 2품목', '음나무순', '돼지족발', '화분스틱1)', '냉동매생이(진도_제휴)', ' 연꽃)', '사과(자홍)', '단감(조안)', '이불', '청귤(제주_제휴)', '잣', '편백짜맞춤쌀통_백이산', '모닝브레드', '꿀비누', '가지 외 8품목', '편백경추베개_백이산', '키위(그린:숙성과)', 'C카)고구마', '히카마', ' 애)', '순모링가분말_순순순', ' 대추방울토마토', '아주까리', '우리밀미니건빵', '가마솥맛누룽지', '블루베리', '적채', '기획행사_농수산물', '황옥녹차 혼합세트', '참매실고-참과일촌', '쇼콜라 견과쿠키', '오이(백다다기)', '발효액', '산머루즙', '도화차-모후실', '순꽃함초자염(항아리)', '엘레강스', '옻나무순(건옻나무순)', '전통장류선물세트_해듬농원', '볶은깨(풍림농원)-순순순', '효향 한끼누룽지(현미)', '절임배추', '양배추(꼬깔)', '동부(밤동부)', '블랙베리(복분자) ...
# [['칡청', '달맞이꽃씨유'], '굼벵이환', '메론', ['차요태', '열매마'], '포도', '꿀', '포도', '사과', '샤인머스켓', '미숫가루', ['밀가루', '쌀'], '사과', '알밤', ['한라봉', '레드향', '천혜향'], '사과', '서복태', ['함양애주', '지리산애주'], ['키고리', '스카프', '가방', '두건'], '로메인 상추', '더덕주', '블루베리', '호두', '새싹인삼', '유정란', '한과', '도라지', ['곶감', '감말랭이'], '딸기', '고로쇠 수액', '지리산도라지와돌배', ['곶감', '말랭이', '사과'], ['딸기', '복수박'], ['두릅', '고사리', '취나물', '누른호박'], '배', ['즙류', 'ABC주스', '우슬진액'], '꿀류', '차류', '미나리', ['두릅', '취나물'], ['머위즙', '삼백초즙'], '블루베리', '신령호두', '부각류', '블루베리', ['가지', '애호박'], '사과', '차류', '아스파라거스', ['담솔', '복분자', '솔송주'], ['고구마', '사과'], ['도마', '주걱'], '약초류', '유기농계란', ['엉겅퀴', '오가피'], ['죽염류', '된장', '치약'], '국화분재', '표고버섯', '도라지', '부각류', '옥수수', ['그린하미과', '컬리플라워'], ['생강청', '산골편강', '도라비배청'], '보리새싹', '레몬머틀', '배', ['고구마', '오란다', '조청산자', '김부각', '강정류'], ['꿀류', '곶감'], ['대파', '양상추'], '곶감', '사과', ['사과즙', '오미자청', '도라지배즙'], ['고구마', '무말랭이', '시래기'], ['사과', '사과즙'], '반쯤깐밤', '산삼캔디', '지리산명월초 티백차', '표고버섯', '우산고로쇠 수액', '본래족발스페셜세트', ['이불', '베개', '목화솜'], ['꾸찌봉차', '꾸지뽕진액'], ['오미자즙', '양파즙'], ['매실원액', '개복숭아원액', '솔순원액'], '고로쇠 수액', '달걀', ['꿀', '화분'], '아스파라거스', '꿀류', '고구마', ['산삼캔디', '산삼젤리'], ['곡물강정', '산삼견과정', '오미자랑'], ['고추부각', '김부각'], ['고추장', '된장', '간장'], '사과', ['국수', '마스크팩', '샴푸', '산삼주'], ['무말랭이', '아주까리잎', '토마토', '열매마'], '지리산 배도라지 생강청', '백봉령', '도라지', '산머루즙골드', ['블루베리진액', '상황버섯진액'], '하늘과맞닿은 사과즙 도라지배즙', '냉동산딸기', ['적양파', '양파'], '감자', '수박', '지리산 꾸찌봉잎차', '산딸기', ['"마늘, 열무, 양파"'], ['"치커리, 상추, 열무, 배추, 호박, 대파, 호박잎"'], ['"마늘, 고추"'], ['"고추, 마늘"'], ['"마늘, 양파"'], '포도', '블루베리', '블루베리', '복숭아', '토종빨강강낭콩', '고추', '새송이', '감자', '완두', ['"살구, 복숭아"'], '당근', '노각오이', ['"바이오체리, 사과대추"'], ['"들깻잎, 참외, 토마토, 호박, 오이, 고추, 대파"'], '대파', '메리골드', '블루베리', ['"참외, 고추, 들깻잎"'], '포도', ['"가리비, 굴"'], '옥수수', '포도', '포도', ['"개구리참외, 복수박, 사과참외, 들깻잎"'], '고추', '딸기', ['토마토', '오이'], '목이', '아스파라거스', '아스파라거스', '표고', '체리', '아스파라거스', '표고', '감자', ['"감자, 고구마"'], '감자', '마늘', ['"토마토, 방울토마토, 양파"'], '감자', '블루베리', '블루베리', '오디', '오디', '마늘', ['"마늘, 양파, 고수"'], '홍감자', '감자', '블루베리', '감자', '감자', '감자', '감자', ['"감자, 고구마"'], '완두', '완두', '완두', '잠두', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '딸기', ['아스파라거스', '열무'], '표고', ['딸기', '오이'], '목이', ['시금치', '상추', '오이'], ['상추', '양상추', '양배추', '아스파라거스'], '딸기', '아스파라거스', '표고', '표고', '목이', '아스파라거스', ['토종근대', '토종아욱', '돌미나리 등'], ['표고', '목이'], '표고', '감자', '들깨', '참깨', ['서리태', '콩나물콩'], '딸기', '딸기', '딸기', '딸기', ['상추', '토마토', '오이'], '딸기', '감자', '감자', '상추', '딸기', '딸기', '느타리', '딸기', ['오이', '호박'], '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', '물김', ['들깻잎', '무', '배추', '알타리'], '만차랑단호박', ['고추', '무', '배추'], '들깨', ['무', '배추'], '토마토', '들깨', '딸기', '딸기', '딸기', '딸기', '딸기', '딸기', '딸기', '딸기', '딸기', '수수', '수수', '대두', ['대두', '쥐눈이콩', '팥'], ['서리태', '푸른콩'], '서리태', '작두콩', '서리태', '대추', '딸기', '딸기', '딸기', '딸기', '딸기', '배추', ['무', '배추'], '배추', '들깨', '고구마', '고구마', '사과', ['고추', '무', '배추'], '무', ['머위', '얼갈이배추', '대파', '고추 등'], ['대파', '부추', '배추', '무', '호박 등'], '고추', '양배추', '더덕', '찹쌀', '감자', ['녹두', '대두'], '팥', '은행', '배추', '고추', ['배추', '무'], ['고추', '얼갈이배추', '부추', '상추 등'], ['참깨', '들깨'], '고구마', '작두콩', '고추', '대추방울토마토', ['새싹인삼', '새싹더덕', '새싹도라지'], '결명자', '고구마', ['시금치', '쪽파', '배추', '열무'], ['참나물', '부추'], '표고', '쌀', ['대두', '두유콩', '서리태'], ['고추', '무', '배추', '쪽파'], '고구마', '고구마', '고구마', '배', '토란대', ['고추', '무', '배추'], ['고추', '무', '배추', '알타리'], ['고추', '무'], ['고추', '무', '배추', '쪽파'], ['고구마', '돼지감자'], ['감자', '고구마'], ['쪽파', '대파', '고추', '무', '배추', '아스파라거스'], ['검정깨', '참깨'], '쌀', '고구마', '고구마', '사과', '미니사과', '배', ['시금치', '고추', '무', '배추 등'], ['냉이', '달래', '상추', '쪽파', '땅두릅'], ['오이', '토마토'], '고추', ['고추', '단호박'], '두릅', '두릅', '표고', ['무', '배추'], '혼합현미', '쌀', ['찹쌀(백옥찰)', '찹쌀(적진주찰)'], '대두', ['당근', '대파', '시금치'], '포도', '포도', '포도', '포도', '포도', '포도', '포도', '포도', '포도', '감자', ['밤', '은행', '참다래', '포도'], '포도', ['고추', '상추', '양파'], ['대파', '무', '부추'], '쌀', '쌀', '쌀', '쌀', '쌀', '쌀', '쌀', '쌀', '쌀', '쌀', '쌀', '쌀', '고구마', ['감자', '고구마'], '고구마', '고구마', '고구마', '고구마', '고구마', '고구마', '상추', '양파', '단호박', '감자', '복숭아', '고추', '마늘', '쥐눈이콩', '참깨', '메주콩', '딸기', '고추', '오이', '부추' ...

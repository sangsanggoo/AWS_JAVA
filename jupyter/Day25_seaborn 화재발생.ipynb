# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
f_path = "c:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

pd_data = pd.read_csv('시도별_화재발생_현황_총괄__20230307153833.csv',encoding='cp949')
pd_data.head()
# Out:
#      시점  행정구역별  건수 (건) 사망 (명)  부상 (명)  재산피해(계) (천원)   부동산 (천원)    동산 (천원)  \
# 0  2010     전국   41863    304    1588     266776332  117808118  148968214
# 1  2010  서울특별시    5321     42     188      14503873    5948963    8554910
# 2  2010  부산광역시    2403     19      91      10546785    5580443    4966342
# 3  2010  대구광역시    1923     12      72       4637285    1996359    2640926
# 4  2010  인천광역시    1746     15      65      11614854    5362442    6252412
#
#    이재가구수 (가구)  이재민수 (명)
# 0        1183      2623
# 1         131       277
# 2          46       126
# 3          62       137
# 4          68       167

# %%
sns.lineplot(data=pd_data,x='시점',y='이재가구수 (가구)')
sns.heatmap(pd_data['이재가구수 (가구)'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 sns.lineplot(data=pd_data,x='시점',y='이재가구수 (가구)')
# ----> 2 sns.heatmap(pd_data['이재가구수 (가구)'])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\matrix.py:115, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     112 # Validate the mask and convert to DataFrame
#     113 mask = _matrix_mask(data, mask)
# --> 115 plot_data = np.ma.masked_where(np.asarray(mask), plot_data)
#     117 # Get good names for the rows and columns
#     118 xtickevery = 1
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\ma\core.py:1933, in masked_where(condition, a, copy)
#    1931 (cshape, ashape) = (cond.shape, a.shape)
#    1932 if cshape and cshape != ashape:
# -> 1933     raise IndexError("Inconsistent shape between the condition and the input"
#    1934                      " (got %s and %s)" % (cshape, ashape))
#    1935 if hasattr(a, '_mask'):
#    1936     cond = mask_or(cond, a._mask)
#
# IndexError: Inconsistent shape between the condition and the input (got (214, 1) and (214,))

# %%
sns.pairplot(pd_data)

# %%
sns.displot(data=pd_data,x='시점',y='')

# %%
df1 =

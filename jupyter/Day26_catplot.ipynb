# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
f_path = "c:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

pd_data = pd.read_csv('화재통계.csv',encoding='cp949')
pd_tips = sns.load_dataset('tips')

# %%
sns.catplot(data=pd_tips , x = 'day',y ='total_bill',jitter = 0.2,hue = 'smoker', dodge = True)
#sns.relplot(data=pd_tips , x = 'day',y ='total_bill')

# %%
pd_data.head()
# Out:
#     구분   시명  화재건수  사망   부상  인명피해 계  부동산피해(천원)  동산피해(천원)  재산피해(천원)  재산피해/건당(천원)
# 0   합계  NaN  4172  39  201     240   26081237  35155563  61236800        14678
# 1  강원도   소계   206   6    9      15    7800727   6173294  13974021        67835
# 2  NaN  강릉시    21   0    1       1      95045     16342    111387         5304
# 3  NaN  고성군    11   0    1       1      65848     41622    107470         9770
# 4  NaN  동해시     6   0    1       1      10206     13434     23640         3940

# %%
sns.relplot(data=pd_data,x='구분',y='화재건수',)

# %%
sns.displot(data=pd_data, x=pd_data['구분'],y='부동산피해(천원)')

# %%
pd_data.plot.line(x='구분',y={'사망','부상'})
# Out:
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_8252\2447379771.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   pd_data.plot.line(x='구분',y={'사망','부상'})
# <AxesSubplot: xlabel='구분'>

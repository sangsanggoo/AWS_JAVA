# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
f_path = "c:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

fig, axe = plt.subplots()
axe.plot(np.sin(np.linspace(-1.0,1.0,10)))
# Out:
# C:\Users\ITPS\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\ITPS\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
fig1 = plt.figure(layout='tight')
ax1 = fig1.add_subplot(3,2,1)
ax1 = fig1.add_subplot(3,2,2)
ax1 = fig1.add_subplot(3,1,2)
ax1 = fig1.add_subplot(3,1,3)

# %%
pd_data= pd.read_csv('이륜차신고현황_시도별_20230309170647.csv',encoding='cp949',header =2)
pd_data.columns = list(['시도명','시점','구명','계','경형','소형','중형','대형','계(관용)','경형(관용)','소형(관용)','중형(관용)','대형(관용)','계(자가용)','경형(자가용)','소형(자가용)','중형(자가용)','대형(자가용)'])
pd_data
# Out:
#    시도명       시점    구명      계   경형    소형     중형    대형  계(관용)  경형(관용)  소형(관용)  \
# 0   부산  2023.01   강서구   5919  364  1795   3208   552     51       3       8
# 1   부산  2023.01    중구   3017   99   678   2099   141     89       0      20
# 2   부산  2023.01   금정구   8175  350  2072   5178   575     79       5       4
# 3   부산  2023.01   기장군   5886  311  1473   3475   627     68       2       8
# 4   부산  2023.01    남구  10764  451  2408   6964   941     31       3      10
# 5   부산  2023.01    동구   4478  185   963   3009   321     57       2      22
# 6   부산  2023.01   동래구   8976  404  2133   5584   855     74       1       1
# 7   부산  2023.01  부산진구  16046  633  3922  10094  1397    118      10      21
# 8   부산  2023.01    북구   8741  414  2075   5532   720     50       1       4
# 9   부산  2023.01   사상구   9444  576  2276   5989   603    161      26      38
# 10  부산  2023.01   사하구  12553  528  2888   8168   969     80       6       2
# ...

# %%
fig1 = plt.figure(layout='tight')

left = fig1.add_subplot(1,2,1)
right = fig1.add_subplot(1,2,2)
goo_plot = sns.relplot(data=pd_data,x='구명',y='계')
left.goo_plot
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 6
#       4 right = fig1.add_subplot(1,2,2)
#       5 goo_plot = sns.relplot(data=pd_data,x='구명',y='계')
# ----> 6 left.goo_plot
#
# AttributeError: 'AxesSubplot' object has no attribute 'goo_plot'

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
f_path = "c:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

pd_data= pd.read_csv('park.csv')
pd_data
# Out:
#           지자체명  공원구분             공원명         위도          경도      공원면적  \
# 0        서울특별시   소공원           녹색소공원  37.539217  126.962694    1569.9
# 1      세종특별자치시   소공원   푸름샘 소공원(소1-1)  36.516117  127.233781    1820.0
# 2      세종특별자치시   소공원    솔숲 소공원(소1-2)  36.508995  127.230040    1037.0
# 3      세종특별자치시  수변공원  마디꽃 수변공원(수1-1)  36.495962  127.257316    4928.0
# 4      세종특별자치시  수변공원    꽃 수변공원(수2-3)  36.473133  127.254482    3575.0
# ...        ...   ...             ...        ...         ...       ...
# 17576    서울특별시    기타              방배  37.474225  126.995298  210517.2
# 17577    서울특별시    기타            말죽거리  37.480885  127.030469  280822.6
# 17578    서울특별시  근린공원             서리풀  37.484654  127.000420  465938.3
# 17579    서울특별시  근린공원              방배  37.470535  126.989600   74847.6
# 17580    서울특별시  근린공원            말죽거리  37.479294  127.029304  132020.3
#
#             지정고시일
# 0      2012-10-19
# 1      2011-08-05
# 2      2011-08-05
# 3      2007-07-04
# 4      2009-01-07
# ...           ...
# 17576         NaN
# 17577         NaN
# 17578         NaN
# 17579         NaN
# 17580         NaN
#
# [17581 rows x 7 columns]

# %%
#pd_data.pivot('지자체명','공원구분','공원면적')
g1 = pd_data.groupby(['지자체명','공원구분'])
df_group = g1.mean()
df_group_pv = df_group.reset_index().pivot('지자체명','공원구분','공원면적')
print(df_group_pv)
sns.heatmap(df_group_pv)
# Out:
# 공원구분              근린공원             기타     도시농업공원      도시자연공원         마을마당  \
# 지자체명
# 강원도       72163.945614   33815.428571  1991830.0  1438344.50          NaN
# 경기도       69600.723833   10985.209719    22263.5         NaN          NaN
# 경상남도     109601.130739            NaN        NaN         NaN          NaN
# 경상북도     102832.436563  365820.000000        NaN         NaN          NaN
# 광주광역시     58197.585608            NaN    49805.9         NaN          NaN
# 대구광역시    107637.043262    2133.271429        NaN         NaN          NaN
# 대전광역시    102164.516049   13204.666667        NaN         NaN          NaN
# 부산광역시    180711.652482  102117.412778    50417.0         NaN          NaN
# 서울특별시    141823.443505  327549.464789  1902047.5  6012153.65  1115.387755
# 세종특별자치시   79185.956522            NaN        NaN         NaN          NaN
# 울산광역시    257856.992982  315720.954545        NaN         NaN          NaN
# 인천광역시    117710.879869  201580.000000        NaN         NaN          NaN
# 전라남도     141764.380288    6000.136508        NaN   495740.00          NaN
# 전라북도     170762.910440            NaN        NaN         NaN          NaN
# 제주특별자치도  107904.490789            NaN        NaN         NaN          NaN
# 충청남도      77128.350339  111164.700000        NaN         NaN          NaN
# 충청북도      68908.201786  332369.055556        NaN         NaN          NaN
#
# 공원구분           묘지공원           문화공원          소공원           수변공원         어린이공원  \
# 지자체명
# 강원도       178931.00   63918.800000  2178.651408   20905.555556   2370.343284
# 경기도       427488.00   45792.573984  1766.839961   37042.070000   2660.348448
# 경상남도     1203543.00   46535.228125  2215.305925   35466.600000   2338.830308
# 경상북도            NaN   36679.056565  1637.597299   59779.678571   2211.241245
# 광주광역시     601730.00   13125.200000  1154.510680  202215.000000   2306.561250
# 대구광역시      28751.00   26380.814286  1810.358929   68239.933333   2138.772319
# 대전광역시    3235379.00   36445.078571  1447.817021   36388.766667  16686.630824
# 부산광역시     473472.00   12789.216667  2152.321622  231742.042857   2223.140379
# 서울특별시      13224.00   21278.712308  8089.744177   25077.433333   5172.333770
# 세종특별자치시         NaN  181244.500000  1428.500000   26687.333333   2828.588235
# 울산광역시     228707.10   17114.700000  2365.659524   30130.000000   2241.506623
# 인천광역시    1654884.00   58734.300000  1657.220455   13502.000000   3130.759233
# 전라남도      396899.50   69032.071429  3016.200912   27681.197917   8398.109440
# 전라북도      228183.75   53900.210526  1890.075382   48350.250000   2229.189836
# 제주특별자치도         NaN   76904.600000  4012.333333  104137.000000   2451.278808
# 충청남도      188835.75   37557.150000  3394.807532   15088.954054   3684.662091
# 충청북도     1501511.00   40682.272727  1801.004930   15246.966667   2143.141741
#
# 공원구분              역사공원      주제공원           체육공원
# 지자체명
# 강원도       10591.400000       NaN  242031.125000
# 경기도      122907.665789       NaN   43020.350962
# 경상남도      32962.625000       NaN   75516.533333
# 경상북도      40593.184615       NaN   28738.820000
# 광주광역시     18526.755385       NaN   30349.942857
# 대구광역시      1585.000000       NaN  232520.410000
# 대전광역시     56465.366667       NaN   54507.372727
# 부산광역시     54187.000000       NaN    8355.200000
# 서울특별시     21776.429412  31289.45  247248.433333
# 세종특별자치시   17549.000000       NaN   13570.000000
# 울산광역시     86591.566667       NaN  723570.250000
# 인천광역시              NaN       NaN   24079.400000
# 전라남도      22840.250000       NaN   76332.206667
# 전라북도     300233.000000       NaN  128482.750000
# 제주특별자치도    6270.666667       NaN  118946.500000
# 충청남도      57854.633333       NaN   64084.657692
# 충청북도      43092.090909       NaN   75066.500000
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_11960\2204003138.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_group = g1.mean()
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_11960\2204003138.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_group_pv = df_group.reset_index().pivot('지자체명','공원구분','공원면적')
# <AxesSubplot: xlabel='공원구분', ylabel='지자체명'>

# %%
g1 = pd_data.groupby(['지자체명','공원구분'])
df_group = g1.count()
df_group_pv = df_group.reset_index().pivot('지자체명','공원구분','공원면적')
print(df_group_pv)
sns.heatmap(df_group_pv)
# Out:
# 공원구분       근린공원     기타  도시농업공원  도시자연공원  마을마당  묘지공원   문화공원    소공원   수변공원  \
# 지자체명
# 강원도       114.0    7.0     1.0     2.0   NaN   1.0   20.0  142.0    9.0
# 경기도      1007.0  391.0     2.0     NaN   NaN  12.0  123.0  513.0  110.0
# 경상남도      257.0    NaN     NaN     NaN   NaN   3.0   32.0  198.0   19.0
# 경상북도      197.0    1.0     NaN     NaN   NaN   NaN   23.0  147.0   28.0
# 광주광역시     189.0    NaN     1.0     NaN   NaN   3.0    5.0  103.0    8.0
# 대구광역시     141.0    7.0     NaN     NaN   NaN   1.0    7.0   56.0    6.0
# 대전광역시      81.0    3.0     NaN     NaN   NaN   1.0   14.0   47.0    6.0
# 부산광역시     141.0   18.0     1.0     NaN   NaN   2.0   18.0  111.0    7.0
# 서울특별시     368.0   71.0     2.0     2.0  49.0   1.0   26.0  249.0    6.0
# 세종특별자치시    23.0    NaN     NaN     NaN   NaN   NaN    4.0    2.0    3.0
# 울산광역시      57.0   11.0     NaN     NaN   NaN   2.0    2.0   84.0    2.0
# 인천광역시     206.0    1.0     NaN     NaN   NaN   1.0    7.0   44.0    4.0
# 전라남도      208.0   63.0     NaN     1.0   NaN   2.0   28.0  329.0   48.0
# 전라북도      218.0    NaN     NaN     NaN   NaN   4.0   19.0  107.0    8.0
# 제주특별자치도    76.0    NaN     NaN     NaN   NaN   NaN    5.0    3.0    1.0
# 충청남도      443.0   10.0     NaN     NaN   NaN   4.0   32.0  385.0   37.0
# 충청북도      224.0    9.0     NaN     NaN   NaN   1.0   11.0  142.0   27.0
#
# 공원구분      어린이공원  역사공원  주제공원   체육공원
# 지자체명
# 강원도       335.0   5.0   NaN    8.0
# 경기도      2126.0  38.0   NaN  104.0
# 경상남도      617.0  16.0   NaN   21.0
# 경상북도      599.0  13.0   NaN   10.0
# 광주광역시     560.0  13.0   NaN    7.0
# 대구광역시     401.0   2.0   NaN   10.0
# 대전광역시     279.0   3.0   NaN   11.0
# 부산광역시     369.0   4.0   NaN    3.0
# 서울특별시    1146.0  17.0   2.0    6.0
# 세종특별자치시    34.0   3.0   NaN    1.0
# 울산광역시     302.0   3.0   NaN    4.0
# 인천광역시     417.0   NaN   NaN   10.0
# 전라남도      339.0  16.0   NaN   15.0
# 전라북도      305.0   6.0   NaN    4.0
# 제주특별자치도   151.0   3.0   NaN    6.0
# 충청남도      794.0  33.0   NaN   26.0
# 충청북도      359.0  11.0   NaN    6.0
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_11960\3071249304.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_group_pv = df_group.reset_index().pivot('지자체명','공원구분','공원면적')
# <AxesSubplot: xlabel='공원구분', ylabel='지자체명'>
